# %%
# Importing all necessary libraries
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
import numpy as np
import pandas as pd
import os

# %%
#my code
test_total = 0
valid_total = 0
train_total = 0
for image in os.listdir("/kaggle/input/mymulticlass/Test_DataSet_MultiClass/Test_DataSet_MultiClass/motorbikes/"):
    if image.endswith(".jpg"):
        test_total = test_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Test_DataSet_MultiClass/Test_DataSet_MultiClass/planes/"):
    if image.endswith(".jpg"):
        test_total = test_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Test_DataSet_MultiClass/Test_DataSet_MultiClass/schooners/"):
    if image.endswith(".jpg"):
        test_total = test_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Train_DataSet_MultiClass/Train_DataSet_MultiClass/motorbikes/"):
    if image.endswith(".jpg"):
        train_total = train_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Train_DataSet_MultiClass/Train_DataSet_MultiClass/planes/"):
    if image.endswith(".jpg"):
        train_total = train_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Train_DataSet_MultiClass/Train_DataSet_MultiClass/schooners/"):
    if image.endswith(".jpg"):
        train_total = train_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Validation_DataSet_MultiClass/Validation_DataSet_MultiClass/motorbikes/"):
    if image.endswith(".jpg"):
        valid_total = valid_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Validation_DataSet_MultiClass/Validation_DataSet_MultiClass/planes/"):
    if image.endswith(".jpg"):
        valid_total = valid_total + 1
for image in os.listdir("/kaggle/input/mymulticlass/Validation_DataSet_MultiClass/Validation_DataSet_MultiClass/schooners/"):
    if image.endswith(".jpg"):
        valid_total = valid_total + 1
print("Test total: ", test_total, "Train total: ", train_total, "Valid total: ", valid_total)
print("Total: ", test_total + train_total + valid_total)
#mycode
# Out:
# Test total:  331 Train total:  998 Valid total:  332
# Total:  1661

# %%
img_width, img_height = 224, 224 #Geeks for Geeks article
train_data_dir = '/kaggle/input/mymulticlass/Train_DataSet_MultiClass/Train_DataSet_MultiClass/' #Geeks for Geeks article
test_data_dir = '/kaggle/input/mymulticlass/Test_DataSet_MultiClass/Test_DataSet_MultiClass/' #Geeks for Geeks article
validation_data_dir = '/kaggle/input/mymulticlass/Validation_DataSet_MultiClass/Validation_DataSet_MultiClass/' #Geeks for Geeks article

# %%
#Geeks for Geeks article
epochs = 10
batch_size = 16
#Geeks for Geeks article

# %%
#Geeks for Geeks article
"""if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
  
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
  
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
  
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])"""
#Geeks for Geeks article
# Out:
# "if K.image_data_format() == 'channels_first':\n    input_shape = (3, img_width, img_height)\nelse:\n    input_shape = (img_width, img_height, 3)\n    \nmodel = Sequential()\nmodel.add(Conv2D(32, (2, 2), input_shape=input_shape))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(2, 2)))\n  \nmodel.add(Conv2D(32, (2, 2)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(2, 2)))\n  \nmodel.add(Conv2D(64, (2, 2)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(2, 2)))\n  \nmodel.add(Flatten())\nmodel.add(Dense(64))\nmodel.add(Activation('relu'))\nmodel.add(Dropout(0.5))\nmodel.add(Dense(1))\nmodel.add(Activation('sigmoid'))\n\nmodel.compile(loss='binary_crossentropy',\n              optimizer='rmsprop',\n              metrics=['accuracy'])"

# %%
#My code, but it's the geeks for geeks kind of modified

model = Sequential() 
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])

#My code, but it's the geeks for geeks kind of modified

# %%
#experiment #1 adding a layer
"""
model = Sequential() 
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])
"""
# Out:
# "\nmodel = Sequential() \nmodel.add(Conv2D(32, (3, 3), input_shape=input_shape))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n\nmodel.add(Conv2D(32, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Conv2D(64, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n\nmodel.add(Conv2D(32, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Flatten())\nmodel.add(Dense(32))\nmodel.add(Activation('relu'))\nmodel.add(Dropout(0.5))\nmodel.add(Dense(3))\nmodel.add(Activation('softmax'))\n\nmodel.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])\n"

# %%
#experiment #2 doubling epochs
"""
epochs = 20

model = Sequential() 
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])
"""
# Out:
# "\nepochs = 20\n\nmodel = Sequential() \nmodel.add(Conv2D(32, (3, 3), input_shape=input_shape))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n\nmodel.add(Conv2D(32, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Conv2D(64, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Flatten())\nmodel.add(Dense(64))\nmodel.add(Activation('relu'))\nmodel.add(Dropout(0.5))\nmodel.add(Dense(3))\nmodel.add(Activation('softmax'))\n\nmodel.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])\n"

# %%
#experiment #3 doubling batch size
"""
batch_size = 32

model = Sequential() 
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
  
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])
"""
# Out:
# "\nbatch_size = 32\n\nmodel = Sequential() \nmodel.add(Conv2D(32, (3, 3), input_shape=input_shape))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n\nmodel.add(Conv2D(32, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Conv2D(64, (3, 3)))\nmodel.add(Activation('relu'))\nmodel.add(MaxPooling2D(pool_size=(3, 3)))\n  \nmodel.add(Flatten())\nmodel.add(Dense(64))\nmodel.add(Activation('relu'))\nmodel.add(Dropout(0.5))\nmodel.add(Dense(3))\nmodel.add(Activation('softmax'))\n\nmodel.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['categorical_crossentropy'])\n"

# %%
# medium tutorial all of it
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

valid_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    shuffle=True)
  
validation_generator = valid_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    shuffle=True)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=1,
    class_mode=None,
    color_mode="rgb",
    shuffle=False
)

model.fit(train_generator,steps_per_epoch=train_total//batch_size,epochs=epochs,validation_data=validation_generator,validation_steps=valid_total//batch_size)
# medium tutorial all of it
# Out:
# Found 998 images belonging to 3 classes.
# Found 332 images belonging to 3 classes.
# Found 331 images belonging to 3 classes.
# Epoch 1/10
# 62/62 [==============================] - 27s 428ms/step - loss: 0.8473 - categorical_crossentropy: 0.8473 - val_loss: 0.7942 - val_categorical_crossentropy: 0.7942
# Epoch 2/10
# 62/62 [==============================] - 26s 417ms/step - loss: 0.7169 - categorical_crossentropy: 0.7169 - val_loss: 0.7156 - val_categorical_crossentropy: 0.7156
# Epoch 3/10
# 62/62 [==============================] - 26s 421ms/step - loss: 0.5894 - categorical_crossentropy: 0.5894 - val_loss: 0.8445 - val_categorical_crossentropy: 0.8445
# Epoch 4/10
# 62/62 [==============================] - 26s 424ms/step - loss: 0.5369 - categorical_crossentropy: 0.5369 - val_loss: 0.6192 - val_categorical_crossentropy: 0.6192
# Epoch 5/10
# ...

# %%
# medium tutorial
step_size = test_generator.n//test_generator.batch_size
test_generator.reset()
pred_class_indices = np.argmax(model.predict(test_generator,steps=step_size, verbose=1), axis=-1)
# medium tutorial all
# Out:
# 331/331 [==============================] - 3s 9ms/step

# %%
# medium tutorial
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in pred_class_indices]
filenames=test_generator.filenames
# medium tutorial

# %%
#my code
correct = 0
for i in range(331):
    if not filenames[i].find(predictions[i]):
        correct = correct + 1
print("Accuracy: %", correct/331)
#my code
# Out:
# Accuracy: % 0.9577039274924471
